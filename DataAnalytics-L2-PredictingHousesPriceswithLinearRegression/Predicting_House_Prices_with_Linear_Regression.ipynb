# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('all-data.csv', encoding='ISO-8859-1', header=None)
df.columns = ['Sentiment', 'Text']
df.head()
# Out:
#   Sentiment                                               Text
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
print(df.shape)
print(df['Sentiment'].value_counts())
# Out:
# (4846, 2)
# Sentiment
# neutral     2879
# positive    1363
# negative     604
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Sentiment', data=df, palette='viridis')
plt.title('Sentiment Distribution')
plt.show()
# Out:
# /tmp/ipykernel_712/3504553026.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=df, palette='viridis')

# %%
df['Text_Length'] = df['Text'].apply(lambda x: len(str(x).split()))
plt.figure(figsize=(7,4))
sns.boxplot(x='Sentiment', y='Text_Length', data=df)
plt.title('Text Length by Sentiment')
plt.show()

# %%
avg_len = df.groupby('Sentiment')['Text_Length'].mean()
avg_len.plot(kind='bar', figsize=(6,4))
plt.title('Average Words by Sentiment')
plt.ylabel('Avg Words')
plt.show()

# %%
from collections import Counter
words = ' '.join(df['Text']).lower().split()
common = Counter(words).most_common(15)
print(common)
# Out:
# [('the', 6066), ('.', 4780), (',', 4662), ('of', 3213), ('in', 2969), ('and', 2593), ('to', 2509), ('a', 1714), ('for', 1151), ('eur', 1015), ("'s", 1000), ('is', 928), ('will', 850), ('company', 848), ('from', 768)]
